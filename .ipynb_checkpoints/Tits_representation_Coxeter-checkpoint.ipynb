# %%
# Input the complete matrix, not just lower triangular

coxeter_matrix = matrix([[1,3,2], [3,1,6],[2,6,1]])

dim_v = coxeter_matrix.rank()
# Vector space over the reals with 100 bits of precision
v = VectorSpace(RealField(100),dim_v)

# %%
coxeter_matrix
# Out:
# [1 3 2]
# [3 1 6]
# [2 6 1]

# %%
def bilinear(x,y):
    '''Computes the bilinear form of two roots'''
    temp = 0
    for i in range(dim_v):
        for j in range(dim_v):
            temp += x[i]*y[j]*(-cos(pi/coxeter_matrix[i,j]))
    return temp

def s(i):
    '''Returns the ith simple root'''
    return v.basis()[i]

def simple_reflection(s,x):
    return x-2*bilinear(x,s)*s

def w_action(word_list,x):
    '''Input a word w in the generators as a list and a root \alpha. Returns w(\alpha)'''
    temp_x = x
    word_list.reverse()
    
    for s in word_list:
        temp_x = simple_reflection(s,temp_x)
    
    # reverse back is it reverses the word outside this function as well
    word_list.reverse()
    
    return temp_x

def inversion_set(w):
    '''Returns the left inversion set of an element w as a list'''
    inversionlist = [w[0]]

    for i in range(len(w)-1):        
        # note: w[0:i+1] does not include the endpoint i+1
        temp = w[0:i+1]
        inversionlist.append(w_action(temp,w[i+1]))
        
    return inversionlist

def elementary_roots():
    '''Returns the set of elementary roots'''
    elementary = []
    
    for i in range(dim_v):
        elementary.append(s(i))
    
    temp_n = 1
    counter = 0
    
    while temp_n < len(elementary):
        
        new_root_counter = 0
        
        temp_n = len(elementary)

        for root in elementary[counter:]:
            for i in range(dim_v):

                temp = w_action([s(i)],root)

                if (temp[i] > root[i]) and (temp[i]-root[i] < 2) and temp not in elementary:
                    elementary.append(temp)
                    new_root_counter += 1
        
        counter = len(elementary) - new_root_counter - 1
                      
    return elementary

def elementary_inversion_set(w, elementary):
    '''returns the left elementary inversion set of an element, but compute the elementary roots first and input it, 
       to avoid recalculating it everytime.'''
    
    inver = inversion_set(w)
    
    e_inversion = [root for root in elementary if root in inver]
    
    return e_inversion

def left_length_increase(word, s):
    '''Tells you whether a word increases in length by multiplication by s on the left'''
    
    if word[0] == s:
        return False
    
    word_copy = word[:]
    word_copy.reverse()
    
    root = w_action(word_copy,s)
    
    if sum(root) >= 0:
        return True
    else:
        return False
    
def words_are_same_element(word1, word2):
    '''Given two reduced words, determine whether they are the same element 
    by checking if their inversion sets are the same'''
    
    # this only works because we assume words are reduced
    if len(word1) != len(word2):
        return False
  
    w1_inversion = inversion_set(word1)
    w2_inversion = inversion_set(word2)
        
    for root in w1_inversion:
        if root in w2_inversion:
            w2_inversion.remove(root)
    
    if len(w2_inversion) == 0:
        return True
    else:
        return False

def word_nice(word):
    '''prints word as a string of letters'''
    word_string = ''
    for vector in word:
        if vector == s(0):
            word_string += 's'
        elif vector == s(1):
            word_string += 't'
        elif vector == s(2):
            word_string += 'u'
        else:
            word_string += 'v'
    
    return word_string

def wordnice_to_vectorlist(word):
    '''Given a nice presented word returns a list of simple vectors representing the word for computation'''
    word_list = []
    
    for letter in word:
        if letter == 's':
            word_list.append(s(0))
        if letter == 't':
            word_list.append(s(1))
        if letter == 'u':
            word_list.append(s(2))
        if letter == 'v':
            word_list.append(s(3))
    
    return word_list


def elementary_inversion_lists_same(e1, e2):
    '''given two elementary inversion lists, check whether they are the same as sets'''
    if len(e1) != len(e2):
        return False
    
    e1_copy = e1[:]
    
    for root in e1:
        if root in e2:
            e1_copy.remove(root)
        else:
            return False
    
    if len(e1_copy) == 0:
        return True
    else:
        return False

# %%
elementary = elementary_roots()
len(elementary)
# Out:
# 12

# %% [markdown]
# ## Some code for dihedral root subsystems

# %%
import math

def dihedral_root_system(r1, r2):
    '''Returns the root system for the dihedral group generated by the reflections r1 and r2
       input is two reflections as a list
    '''
    
    # Get root associated to reflection 1
    middle_of_r1 = int(math.ceil(len(r1)/2))
    
    if middle_of_r1 - 2==0:
        root1 = w_action([r1[0]],r1[middle_of_r1 - 1])
    elif middle_of_r1 == 1:
        root1 = r1[0]
    else:
        root1 = w_action(r1[0:middle_of_r1 - 1],r1[middle_of_r1 - 1])
    
    # Get root associated to reflection 2
    middle_of_r2 = int(math.ceil(len(r2)/2))
    
    if middle_of_r2 - 2==0:
        root2 = w_action([r2[0]],r2[middle_of_r2 - 1])
    elif middle_of_r2 == 1:
        root2 = r2[0]
    else:
        root2 = w_action(r2[0:middle_of_r2 - 1],r2[middle_of_r2 - 1])
    
    roots = [root1, root2]
    reflections = [r1, r2]
    
    temp_n = 1
    counter = 0
    
    while temp_n < len(roots):
        
        new_root_counter = 0
        
        temp_n = len(roots)
        
        if temp_n > 200:
            print("Looks like this will be an infinite dihedral group. I'm going to stop!!")
            break
        
        for root in roots[counter:]:
            for re in reflections:
                new_root = w_action(re,root)
                
                if new_root not in roots:
                    roots.append(new_root)
                    new_root_counter += 1
        
        counter = len(roots) - new_root_counter - 1
        
    return roots

def positive_roots(subgroup):
    
    pos_roots = []
    
    for el in subgroup:
        if sum(el) > 0:
            pos_roots.append(el)
            
    return pos_roots

# %%
w_action([s(0),s(2),s(1)], s(2))
# Out:
# (1.00000000000000*sqrt(3), 1.00000000000000*sqrt(3), 2.00000000000000)

# %%
wordnice_to_vectorlist('stu')
# Out:
# [(1.00000000000000, 0.000000000000000, 0.000000000000000),
#  (0.000000000000000, 1.00000000000000, 0.000000000000000),
#  (0.000000000000000, 0.000000000000000, 1.00000000000000)]

# %% [markdown]
# ## Construct the Brink-Howlett automata

# %%
def bh_automata():
    '''Returns the list of states, where each item is a list with first index a state
    and then following items in the list are tuples with a transition letter and target state'''

    # list of states and their transition information
    # as elementary inversion lists
    states_transitions = []
    
    # list of states only (as representative word)
    state_list = ['s', 't', 'u']
    
    counter = 0
    num_of_new_states = 1
    
    while num_of_new_states > 0:
        
        num_of_new_states = 0
        
        for state in state_list[counter:]:
            
            counter = len(state_list)-num_of_new_states
            
            state_vector = wordnice_to_vectorlist(state)
            
            state_elementary = elementary_inversion_set(state_vector, elementary)

            state_info = [state]
            
            for j in range(0,dim(v)):
                #print(' ')
                
                generator_word = word_nice([s(j)])
                #print('Word representing inversion set is: ' + state + ' generator is: ' + generator_word )
                
                if left_length_increase(state_vector,s(j)):

                    #print('Yes, ' + state + ' increases on the left by ' + word_nice([s(j)]))
                    
                    target_state = [s(j)] + state_vector
                    target_state_word = word_nice(target_state)
                    
                    #print('Word repping Target State: ' + target_state_word)
                    
                    target_state_elementary_inversion_set = elementary_inversion_set(target_state, elementary)
                    
                    # If target state elementary inversion set is not in the list of states, add to the list.
                    # if already in list, add appropriate transition
                    target_state_is_new = True
                    
                    for st in state_list:
                        st_elementary = elementary_inversion_set(wordnice_to_vectorlist(st), elementary)
                        
                        if elementary_inversion_lists_same(target_state_elementary_inversion_set, st_elementary):
                            #print('Its inversion set is already represented in state_list. It has same e-inversion set as ' + st)
                            
                            transition = (generator_word, st)
                            state_info.append(transition)
                            
                            #print('Added the transition pair (' + generator_word + ', ' + st )
                            
                            target_state_is_new = False
                            break
                    
                    if target_state_is_new == True:
                        # add target_state rep to state list
                        state_list.append(target_state_word)
                        #print('New State. Adding to state_list, the rep: ' + word_nice(target_state))
                        num_of_new_states += 1
                                
                        transition = (generator_word, target_state_word)
                        state_info.append(transition)
                        #print('Added the transition pair (' + generator_word + ', ' + target_state_word )

                #else:
                    #print('No, ' + state + ' decreases by ' + word_nice([s(j)]))
                    
            states_transitions.append(state_info)
        
         
        #print('num_of_new_states: ' + str(num_of_new_states))
        #print('NUMBER OF STATES IS NOW: ' + str(len(state_list)))
        #print('State reps are: ')
        #print(state_list)
        #print('The COUNTER is at: ' + str(counter))
        
    print('Number of states: ' + str(len(state_list)))
    print(state_list)
    return states_transitions

# %%
g2 = bh_automata()
# Out:
# Number of states: 48
# ['s', 't', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']

# %%
g2
# Out:
# [['s', ('t', 'ts'), ('u', 'us')],
#  ['t', ('s', 'st'), ('u', 'ut')],
#  ['u', ('s', 'us'), ('t', 'tu')],
#  ['ts', ('s', 'sts'), ('u', 'uts')],
#  ['us', ('t', 'tus')],
#  ['st', ('t', 'sts'), ('u', 'ust')],
#  ['ut', ('s', 'ust'), ('t', 'tut')],
#  ['tu', ('s', 'stu'), ('u', 'utu')],
#  ['sts', ('u', 'usts')],
#  ['uts', ('s', 'usts'), ('t', 'tut')],
#  ['tus', ('s', 'stus'), ('u', 'utus')],
#  ['ust', ('t', 'tus')],
#  ['tut', ('s', 'stu'), ('u', 'utut')],
#  ['stu', ('t', 'stus'), ('u', 'ustu')],
#  ['utu', ('s', 'ustu'), ('t', 'tutu')],
#  ['usts', ('t', 'tusts')],
#  ['stus', ('u', 'ustus')],
#  ['utus', ('s', 'ustus'), ('t', 'tutu')],
#  ['utut', ('s', 'ustu'), ('t', 'tutut')],
#  ['ustu', ('t', 'tustu')],
#  ['tutu', ('s', 'stutu'), ('u', 'ututu')],
#  ['tusts', ('s', 'stus'), ('u', 'utusts')],
#  ['ustus', ('t', 'tustus')],
#  ['tutut', ('s', 'stutut'), ('u', 'ututut')],
#  ['tustu', ('s', 'stustu'), ('u', 'utus')],
#  ['stutu', ('t', 'stustu'), ('u', 'ustutu')],
#  ['ututu', ('s', 'ustutu'), ('t', 'ututut')],
#  ['utusts', ('s', 'ustus'), ('t', 'tutut')],
#  ['tustus', ('s', 'stustu'), ('u', 'utusts')],
#  ['stutut', ('t', 'stustu'), ('u', 'ustutut')],
#  ['ututut', ('s', 'ustutut')],
#  ['stustu', ('u', 'ustus')],
#  ['ustutu', ('t', 'tustutu')],
#  ['ustutut', ('t', 'tustutut')],
#  ['tustutu', ('s', 'tustutut'), ('u', 'utustutu')],
#  ['tustutut', ('u', 'utustutut')],
#  ['utustutu', ('s', 'utustutut'), ('t', 'tutustutu')],
#  ['utustutut', ('t', 'tutustutut')],
#  ['tutustutu', ('s', 'stutustutu'), ('u', 'ututu')],
#  ['tutustutut', ('s', 'stutustutut'), ('u', 'ututustutut')],
#  ['stutustutu', ('t', 'stutustutut'), ('u', 'ustutu')],
#  ['stutustutut', ('u', 'ustutustutut')],
#  ['ututustutut', ('s', 'ustutustutut'), ('t', 'ututut')],
#  ['ustutustutut', ('t', 'tustutustutut')],
#  ['tustutustutut', ('s', 'tustutut'), ('u', 'utustutustutut')],
#  ['utustutustutut', ('s', 'utustutut'), ('t', 'tutustutustutut')],
#  ['tutustutustutut', ('s', 'stutustutustutut'), ('u', 'ututut')],
#  ['stutustutustutut', ('t', 'stutustutut'), ('u', 'ustutut')]]

# %%
def Hopcroft(states_transitions):
    '''Applies Hopcroft minimisation to bh-automata'''
    
    # list of states to be emptied
    worklist = []
    
    # worklist starts as a list of strings
    for states in states_transitions:
        worklist.append(states[0])
    
    print("Initial worklist")
    print(worklist)
    
    # copy of list of states inside the list to initiate partition
    # so partition is a list containing one list to start
    partition = [worklist[:]]
    
    print('Initial partition')
    print(partition)
    
    print('Number of partitions initially: ' + str(len(partition)))
    
    while len(worklist) > 0:
        
        print('Number of states is now: ' + str(len(worklist)))
        
        A = worklist[0]
        
        #remove from worklist
        worklist.remove(A)
        
        print('Set of states removed')
        print(A)
            
        if type(A) == str:
            
            for i in range(0,dim_v):
                generator_word = word_nice([s(i)])
                
                states_with_s_i_transition_to_A = []
                
                for st in states_transitions:
                    for transition_info in st[1:]:
                        
                        if transition_info[0] == generator_word and transition_info[1] == A:
                            states_with_s_i_transition_to_A.append(st[0])
                            print(st[0] + ' is a state with ' + generator_word + ' transition to ')
                            print(A)
                
                print('these are the states with ' + generator_word + ' transitions to the single state: ')
                print(A)
                print(states_with_s_i_transition_to_A)
                
                if len(states_with_s_i_transition_to_A) > 0:
                    break
                        
        elif type(A) == list:
            for g in A:
                for i in range(0,dim_v):
                    generator_word = word_nice([s(i)])
                
                    states_with_s_i_transition_to_A = []
                
                    for st in states_transitions:
                        for transition_info in st[1:]:
                            if transition_info[0] == generator_word and transition_info[1] == g[0]:
                                states_with_s_i_transition_to_A.append(st[0])
                                print(st[0] + ' is a state with ' + generator_word + ' transition to ')
                                print(g)
                
                print('these are the states with ' + generator_word + ' transitions to the partition: ')
                print(A)
                print(states_with_s_i_transition_to_A)
                
                if len(states_with_s_i_transition_to_A) > 0:
                    break
                              
        else:
            print('Houston we have a problem')

                        
        if len(states_with_s_i_transition_to_A) > 0:
                
                #counter = 0
                
                #for y in partition[counter:]:
            for y in partition:
                
                print('Element y of partition I am looking at: ')
                print(y)
                    
                y_and_x = [state for state in y if state in states_with_s_i_transition_to_A]

                print('y_and_x is ')
                print(y_and_x)
                    
                y_minus_x = [i for i in y if i not in states_with_s_i_transition_to_A]

                print('y_minus_x is ')
                print(y_minus_x)
                    
                if y_and_x and y_minus_x:
                    index_of_y = partition.index(y)
                    partition.remove(y)
                    partition.insert(index_of_y, y_and_x)
                    partition.insert(index_of_y+1, y_minus_x)
                        
                        #counter += 2

                    print('Partition is now: ')
                    print(partition)
                    
                    print('Number of partitions now: ')
                    print(len(partition))

                    if y in worklist:
                        worklist.remove(y)
                        worklist.append(y_and_x)
                        worklist.append(y_minus_x)
                            
                        print('THE WORKLIST IS NOW:')
                        print(worklist)
                            
                    else: 
                        if len(y_and_x) < len(y_minus_x):
                            worklist.append(y_and_x)
                                
                            print('THE WORKLIST IS NOW:')
                            print(worklist)
                                
                        else:
                            worklist.append(y_minus_x)
                                
                            print('THE LIST OF STATES IS NOW:')
                            print(worklist)
                        
    return partition

# %%
Hopcroft(g2)
# Out:
# Initial worklist
# ['s', 't', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Initial partition
# [['s', 't', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Size of initial partition: 1
# Number of states is now: 48
# Set of states removed
# s
# these are the states with s transitions to the single state:
# s
# []
# these are the states with t transitions to the single state:
# s
# []
# these are the states with u transitions to the single state:
# s
# []
# Number of states is now: 47
# Set of states removed
# t
# these are the states with s transitions to the single state:
# t
# []
# these are the states with t transitions to the single state:
# t
# []
# these are the states with u transitions to the single state:
# t
# []
# Number of states is now: 46
# Set of states removed
# u
# these are the states with s transitions to the single state:
# u
# []
# these are the states with t transitions to the single state:
# u
# []
# these are the states with u transitions to the single state:
# u
# []
# Number of states is now: 45
# Set of states removed
# ts
# these are the states with s transitions to the single state:
# ts
# []
# s is a state with t transition to
# ts
# these are the states with t transitions to the single state:
# ts
# ['s']
# Element y of partition I am looking at:
# ['s', 't', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['s']
# y_minus_x is
# ['t', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['t', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 2
# THE LIST OF STATES IS NOW:
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s']]
# Element y of partition I am looking at:
# ['t', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['t', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 45
# Set of states removed
# us
# u is a state with s transition to
# us
# these are the states with s transitions to the single state:
# us
# ['u']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['t', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['u']
# y_minus_x is
# ['t', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 3
# THE LIST OF STATES IS NOW:
# ['st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u']]
# Element y of partition I am looking at:
# ['t', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['t', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 45
# Set of states removed
# st
# t is a state with s transition to
# st
# these are the states with s transitions to the single state:
# st
# ['t']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['t']
# y_minus_x is
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 4
# THE LIST OF STATES IS NOW:
# ['ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t']]
# Element y of partition I am looking at:
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 45
# Set of states removed
# ut
# these are the states with s transitions to the single state:
# ut
# []
# these are the states with t transitions to the single state:
# ut
# []
# t is a state with u transition to
# ut
# these are the states with u transitions to the single state:
# ut
# ['t']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# ['t']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 44
# Set of states removed
# tu
# these are the states with s transitions to the single state:
# tu
# []
# u is a state with t transition to
# tu
# these are the states with t transitions to the single state:
# tu
# ['u']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# ['u']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 43
# Set of states removed
# sts
# ts is a state with s transition to
# sts
# these are the states with s transitions to the single state:
# sts
# ['ts']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['ts']
# y_minus_x is
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 5
# THE LIST OF STATES IS NOW:
# ['uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts']]
# Element y of partition I am looking at:
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 43
# Set of states removed
# uts
# these are the states with s transitions to the single state:
# uts
# []
# these are the states with t transitions to the single state:
# uts
# []
# ts is a state with u transition to
# uts
# these are the states with u transitions to the single state:
# uts
# ['ts']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# ['ts']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# Set of states removed
# tus
# these are the states with s transitions to the single state:
# tus
# []
# us is a state with t transition to
# tus
# ust is a state with t transition to
# tus
# these are the states with t transitions to the single state:
# tus
# ['us', 'ust']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['us', 'ust']
# y_minus_x is
# ['st', 'ut', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['st', 'ut', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 6
# THE LIST OF STATES IS NOW:
# ['ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust']]
# Element y of partition I am looking at:
# ['st', 'ut', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'ut', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# Set of states removed
# ust
# ut is a state with s transition to
# ust
# these are the states with s transitions to the single state:
# ust
# ['ut']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['st', 'ut', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['ut']
# y_minus_x is
# ['st', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['st', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 7
# THE LIST OF STATES IS NOW:
# ['tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut']]
# Element y of partition I am looking at:
# ['st', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# Set of states removed
# tut
# these are the states with s transitions to the single state:
# tut
# []
# ut is a state with t transition to
# tut
# uts is a state with t transition to
# tut
# these are the states with t transitions to the single state:
# tut
# ['ut', 'uts']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# ['ut']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['st', 'tu', 'sts', 'uts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['uts']
# y_minus_x is
# ['st', 'tu', 'sts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['st', 'tu', 'sts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 8
# THE LIST OF STATES IS NOW:
# ['stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts']]
# Element y of partition I am looking at:
# ['st', 'tu', 'sts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'tu', 'sts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# Set of states removed
# stu
# tu is a state with s transition to
# stu
# tut is a state with s transition to
# stu
# these are the states with s transitions to the single state:
# stu
# ['tu', 'tut']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# []
# y_minus_x is
# ['uts']
# Element y of partition I am looking at:
# ['st', 'tu', 'sts', 'tus', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['tu', 'tut']
# y_minus_x is
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu', 'tut'], ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 9
# THE LIST OF STATES IS NOW:
# ['utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu', 'tut']]
# Element y of partition I am looking at:
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# Set of states removed
# utu
# these are the states with s transitions to the single state:
# utu
# []
# these are the states with t transitions to the single state:
# utu
# []
# tu is a state with u transition to
# utu
# these are the states with u transitions to the single state:
# utu
# ['tu']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# []
# y_minus_x is
# ['uts']
# Element y of partition I am looking at:
# ['tu', 'tut']
# y_and_x is
# ['tu']
# y_minus_x is
# ['tut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 10
# THE WORKLIST IS NOW:
# ['usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut']]
# Element y of partition I am looking at:
# ['tut']
# y_and_x is
# []
# y_minus_x is
# ['tut']
# Element y of partition I am looking at:
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# Set of states removed
# usts
# uts is a state with s transition to
# usts
# these are the states with s transitions to the single state:
# usts
# ['uts']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# ['uts']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['tu']
# y_and_x is
# []
# y_minus_x is
# ['tu']
# Element y of partition I am looking at:
# ['tut']
# y_and_x is
# []
# y_minus_x is
# ['tut']
# Element y of partition I am looking at:
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 41
# Set of states removed
# stus
# tus is a state with s transition to
# stus
# tusts is a state with s transition to
# stus
# these are the states with s transitions to the single state:
# stus
# ['tus', 'tusts']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# []
# y_minus_x is
# ['uts']
# Element y of partition I am looking at:
# ['tu']
# y_and_x is
# []
# y_minus_x is
# ['tu']
# Element y of partition I am looking at:
# ['tut']
# y_and_x is
# []
# y_minus_x is
# ['tut']
# Element y of partition I am looking at:
# ['st', 'sts', 'tus', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['tus', 'tusts']
# y_minus_x is
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus', 'tusts'], ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 11
# THE LIST OF STATES IS NOW:
# ['utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus', 'tusts']]
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 41
# Set of states removed
# utus
# these are the states with s transitions to the single state:
# utus
# []
# these are the states with t transitions to the single state:
# utus
# []
# tus is a state with u transition to
# utus
# tustu is a state with u transition to
# utus
# these are the states with u transitions to the single state:
# utus
# ['tus', 'tustu']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# []
# y_minus_x is
# ['uts']
# Element y of partition I am looking at:
# ['tu']
# y_and_x is
# []
# y_minus_x is
# ['tu']
# Element y of partition I am looking at:
# ['tut']
# y_and_x is
# []
# y_minus_x is
# ['tut']
# Element y of partition I am looking at:
# ['tus', 'tusts']
# y_and_x is
# ['tus']
# y_minus_x is
# ['tusts']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus'], ['tusts'], ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 12
# THE WORKLIST IS NOW:
# ['utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus'], ['tusts']]
# Element y of partition I am looking at:
# ['tusts']
# y_and_x is
# []
# y_minus_x is
# ['tusts']
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['tustu']
# y_minus_x is
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus'], ['tusts'], ['tustu'], ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']]
# Number of partitions now:
# 13
# THE LIST OF STATES IS NOW:
# ['utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut', ['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus'], ['tusts'], ['tustu']]
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'ustus', 'tutut', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 42
# ...
# ['tutustutu']
# y_and_x is
# []
# y_minus_x is
# ['tutustutu']
# Element y of partition I am looking at:
# ['tustus']
# y_and_x is
# []
# y_minus_x is
# ['tustus']
# Element y of partition I am looking at:
# ['ustus']
# y_and_x is
# []
# y_minus_x is
# ['ustus']
# Element y of partition I am looking at:
# ['tutut']
# y_and_x is
# []
# y_minus_x is
# ['tutut']
# Element y of partition I am looking at:
# ['ututu']
# y_and_x is
# []
# y_minus_x is
# ['ututu']
# Element y of partition I am looking at:
# ['ututustutut']
# y_and_x is
# []
# y_minus_x is
# ['ututustutut']
# Element y of partition I am looking at:
# ['ututut']
# y_and_x is
# []
# y_minus_x is
# ['ututut']
# Element y of partition I am looking at:
# ['ustutu']
# y_and_x is
# []
# y_minus_x is
# ['ustutu']
# Element y of partition I am looking at:
# ['tustutu']
# y_and_x is
# []
# y_minus_x is
# ['tustutu']
# Element y of partition I am looking at:
# ['tustutustutut']
# y_and_x is
# ['tustutustutut']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['utustutu']
# y_and_x is
# []
# y_minus_x is
# ['utustutu']
# Element y of partition I am looking at:
# ['utustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['utustutustutut']
# Element y of partition I am looking at:
# ['utustutut']
# y_and_x is
# []
# y_minus_x is
# ['utustutut']
# Element y of partition I am looking at:
# ['tutustutut']
# y_and_x is
# []
# y_minus_x is
# ['tutustutut']
# Element y of partition I am looking at:
# ['ustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['ustutustutut']
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 36
# Set of states removed
# tutustutustutut
# these are the states with s transitions to the single state:
# tutustutustutut
# []
# utustutustutut is a state with t transition to
# tutustutustutut
# these are the states with t transitions to the single state:
# tutustutustutut
# ['utustutustutut']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# []
# y_minus_x is
# ['uts']
# Element y of partition I am looking at:
# ['tu']
# y_and_x is
# []
# y_minus_x is
# ['tu']
# Element y of partition I am looking at:
# ['tut']
# y_and_x is
# []
# y_minus_x is
# ['tut']
# Element y of partition I am looking at:
# ['tus']
# y_and_x is
# []
# y_minus_x is
# ['tus']
# Element y of partition I am looking at:
# ['tusts']
# y_and_x is
# []
# y_minus_x is
# ['tusts']
# Element y of partition I am looking at:
# ['tustu']
# y_and_x is
# []
# y_minus_x is
# ['tustu']
# Element y of partition I am looking at:
# ['utu']
# y_and_x is
# []
# y_minus_x is
# ['utu']
# Element y of partition I am looking at:
# ['utut']
# y_and_x is
# []
# y_minus_x is
# ['utut']
# Element y of partition I am looking at:
# ['utus']
# y_and_x is
# []
# y_minus_x is
# ['utus']
# Element y of partition I am looking at:
# ['usts']
# y_and_x is
# []
# y_minus_x is
# ['usts']
# Element y of partition I am looking at:
# ['utusts']
# y_and_x is
# []
# y_minus_x is
# ['utusts']
# Element y of partition I am looking at:
# ['ustu']
# y_and_x is
# []
# y_minus_x is
# ['ustu']
# Element y of partition I am looking at:
# ['tutu']
# y_and_x is
# []
# y_minus_x is
# ['tutu']
# Element y of partition I am looking at:
# ['tutustutu']
# y_and_x is
# []
# y_minus_x is
# ['tutustutu']
# Element y of partition I am looking at:
# ['tustus']
# y_and_x is
# []
# y_minus_x is
# ['tustus']
# Element y of partition I am looking at:
# ['ustus']
# y_and_x is
# []
# y_minus_x is
# ['ustus']
# Element y of partition I am looking at:
# ['tutut']
# y_and_x is
# []
# y_minus_x is
# ['tutut']
# Element y of partition I am looking at:
# ['ututu']
# y_and_x is
# []
# y_minus_x is
# ['ututu']
# Element y of partition I am looking at:
# ['ututustutut']
# y_and_x is
# []
# y_minus_x is
# ['ututustutut']
# Element y of partition I am looking at:
# ['ututut']
# y_and_x is
# []
# y_minus_x is
# ['ututut']
# Element y of partition I am looking at:
# ['ustutu']
# y_and_x is
# []
# y_minus_x is
# ['ustutu']
# Element y of partition I am looking at:
# ['tustutu']
# y_and_x is
# []
# y_minus_x is
# ['tustutu']
# Element y of partition I am looking at:
# ['tustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['tustutustutut']
# Element y of partition I am looking at:
# ['utustutu']
# y_and_x is
# []
# y_minus_x is
# ['utustutu']
# Element y of partition I am looking at:
# ['utustutustutut']
# y_and_x is
# ['utustutustutut']
# y_minus_x is
# []
# Element y of partition I am looking at:
# ['utustutut']
# y_and_x is
# []
# y_minus_x is
# ['utustutut']
# Element y of partition I am looking at:
# ['tutustutut']
# y_and_x is
# []
# y_minus_x is
# ['tutustutut']
# Element y of partition I am looking at:
# ['ustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['ustutustutut']
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'tutustutustutut', 'stutustutustutut']
# Number of states is now: 35
# Set of states removed
# stutustutustutut
# tutustutustutut is a state with s transition to
# stutustutustutut
# these are the states with s transitions to the single state:
# stutustutustutut
# ['tutustutustutut']
# Element y of partition I am looking at:
# ['s']
# y_and_x is
# []
# y_minus_x is
# ['s']
# Element y of partition I am looking at:
# ['u']
# y_and_x is
# []
# y_minus_x is
# ['u']
# Element y of partition I am looking at:
# ['t']
# y_and_x is
# []
# y_minus_x is
# ['t']
# Element y of partition I am looking at:
# ['ts']
# y_and_x is
# []
# y_minus_x is
# ['ts']
# Element y of partition I am looking at:
# ['us', 'ust']
# y_and_x is
# []
# y_minus_x is
# ['us', 'ust']
# Element y of partition I am looking at:
# ['ut']
# y_and_x is
# []
# y_minus_x is
# ['ut']
# Element y of partition I am looking at:
# ['uts']
# y_and_x is
# []
# y_minus_x is
# ['uts']
# Element y of partition I am looking at:
# ['tu']
# y_and_x is
# []
# y_minus_x is
# ['tu']
# Element y of partition I am looking at:
# ['tut']
# y_and_x is
# []
# y_minus_x is
# ['tut']
# Element y of partition I am looking at:
# ['tus']
# y_and_x is
# []
# y_minus_x is
# ['tus']
# Element y of partition I am looking at:
# ['tusts']
# y_and_x is
# []
# y_minus_x is
# ['tusts']
# Element y of partition I am looking at:
# ['tustu']
# y_and_x is
# []
# y_minus_x is
# ['tustu']
# Element y of partition I am looking at:
# ['utu']
# y_and_x is
# []
# y_minus_x is
# ['utu']
# Element y of partition I am looking at:
# ['utut']
# y_and_x is
# []
# y_minus_x is
# ['utut']
# Element y of partition I am looking at:
# ['utus']
# y_and_x is
# []
# y_minus_x is
# ['utus']
# Element y of partition I am looking at:
# ['usts']
# y_and_x is
# []
# y_minus_x is
# ['usts']
# Element y of partition I am looking at:
# ['utusts']
# y_and_x is
# []
# y_minus_x is
# ['utusts']
# Element y of partition I am looking at:
# ['ustu']
# y_and_x is
# []
# y_minus_x is
# ['ustu']
# Element y of partition I am looking at:
# ['tutu']
# y_and_x is
# []
# y_minus_x is
# ['tutu']
# Element y of partition I am looking at:
# ['tutustutu']
# y_and_x is
# []
# y_minus_x is
# ['tutustutu']
# Element y of partition I am looking at:
# ['tustus']
# y_and_x is
# []
# y_minus_x is
# ['tustus']
# Element y of partition I am looking at:
# ['ustus']
# y_and_x is
# []
# y_minus_x is
# ['ustus']
# Element y of partition I am looking at:
# ['tutut']
# y_and_x is
# []
# y_minus_x is
# ['tutut']
# Element y of partition I am looking at:
# ['ututu']
# y_and_x is
# []
# y_minus_x is
# ['ututu']
# Element y of partition I am looking at:
# ['ututustutut']
# y_and_x is
# []
# y_minus_x is
# ['ututustutut']
# Element y of partition I am looking at:
# ['ututut']
# y_and_x is
# []
# y_minus_x is
# ['ututut']
# Element y of partition I am looking at:
# ['ustutu']
# y_and_x is
# []
# y_minus_x is
# ['ustutu']
# Element y of partition I am looking at:
# ['tustutu']
# y_and_x is
# []
# y_minus_x is
# ['tustutu']
# Element y of partition I am looking at:
# ['tustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['tustutustutut']
# Element y of partition I am looking at:
# ['utustutu']
# y_and_x is
# []
# y_minus_x is
# ['utustutu']
# Element y of partition I am looking at:
# ['utustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['utustutustutut']
# Element y of partition I am looking at:
# ['utustutut']
# y_and_x is
# []
# y_minus_x is
# ['utustutut']
# Element y of partition I am looking at:
# ['tutustutut']
# y_and_x is
# []
# y_minus_x is
# ['tutustutut']
# Element y of partition I am looking at:
# ['ustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['ustutustutut']
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'tutustutustutut', 'stutustutustutut']
# y_and_x is
# ['tutustutustutut']
# y_minus_x is
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'stutustutustutut']
# Partition is now:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus'], ['tusts'], ['tustu'], ['utu'], ['utut'], ['utus'], ['usts'], ['utusts'], ['ustu'], ['tutu'], ['tutustutu'], ['tustus'], ['ustus'], ['tutut'], ['ututu'], ['ututustutut'], ['ututut'], ['ustutu'], ['tustutu'], ['tustutustutut'], ['utustutu'], ['utustutustutut'], ['utustutut'], ['tutustutut'], ['ustutustutut'], ['tutustutustutut'], ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'stutustutustutut']]
# Number of partitions now:
# 36
# THE LIST OF STATES IS NOW:
# [['s'], ['u'], ['t'], ['ts'], ['us', 'ust'], ['ut'], ['uts'], ['tu'], ['tut'], ['tus'], ['tusts'], ['tustu'], ['utu'], ['utut'], ['utus'], ['usts'], ['utusts'], ['ustu'], ['tutu'], ['tutustutu'], ['tustus'], ['ustus'], ['tutut'], ['ututu'], ['ututustutut'], ['ututut'], ['ustutu'], ['tustutu'], ['tustutustutut'], ['utustutu'], ['utustutustutut'], ['utustutut'], ['tutustutut'], ['ustutustutut'], ['tutustutustutut']]
# Element y of partition I am looking at:
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'stutustutustutut']
# y_and_x is
# []
# y_minus_x is
# ['st', 'sts', 'stu', 'stus', 'stutu', 'stutut', 'stustu', 'ustutut', 'tustutut', 'stutustutu', 'stutustutut', 'stutustutustutut']
# Number of states is now: 35
# Set of states removed
# ['s']
# these are the states with u transitions to the partition:
# ['s']
# []
# Number of states is now: 34
# Set of states removed
# ['u']
# these are the states with u transitions to the partition:
# ['u']
# []
# Number of states is now: 33
# Set of states removed
# ['t']
# these are the states with u transitions to the partition:
# ['t']
# []
# Number of states is now: 32
# Set of states removed
# ['ts']
# these are the states with u transitions to the partition:
# ['ts']
# []
# Number of states is now: 31
# Set of states removed
# ['us', 'ust']
# these are the states with u transitions to the partition:
# ['us', 'ust']
# []
# these are the states with u transitions to the partition:
# ['us', 'ust']
# []
# Number of states is now: 30
# Set of states removed
# ['ut']
# these are the states with u transitions to the partition:
# ['ut']
# []
# Number of states is now: 29
# Set of states removed
# ['uts']
# these are the states with u transitions to the partition:
# ['uts']
# []
# Number of states is now: 28
# Set of states removed
# ['tu']
# these are the states with u transitions to the partition:
# ['tu']
# []
# Number of states is now: 27
# Set of states removed
# ['tut']
# these are the states with u transitions to the partition:
# ['tut']
# []
# Number of states is now: 26
# Set of states removed
# ['tus']
# these are the states with u transitions to the partition:
# ['tus']
# []
# Number of states is now: 25
# Set of states removed
# ['tusts']
# these are the states with u transitions to the partition:
# ['tusts']
# []
# Number of states is now: 24
# Set of states removed
# ['tustu']
# these are the states with u transitions to the partition:
# ['tustu']
# []
# Number of states is now: 23
# Set of states removed
# ['utu']
# these are the states with u transitions to the partition:
# ['utu']
# []
# Number of states is now: 22
# Set of states removed
# ['utut']
# these are the states with u transitions to the partition:
# ['utut']
# []
# Number of states is now: 21
# Set of states removed
# ['utus']
# these are the states with u transitions to the partition:
# ['utus']
# []
# Number of states is now: 20
# Set of states removed
# ['usts']
# these are the states with u transitions to the partition:
# ['usts']
# []
# Number of states is now: 19
# Set of states removed
# ['utusts']
# these are the states with u transitions to the partition:
# ['utusts']
# []
# Number of states is now: 18
# Set of states removed
# ['ustu']
# these are the states with u transitions to the partition:
# ['ustu']
# []
# Number of states is now: 17
# Set of states removed
# ['tutu']
# these are the states with u transitions to the partition:
# ['tutu']
# []
# Number of states is now: 16
# Set of states removed
# ['tutustutu']
# these are the states with u transitions to the partition:
# ['tutustutu']
# []
# Number of states is now: 15
# Set of states removed
# ['tustus']
# these are the states with u transitions to the partition:
# ['tustus']
# []
# Number of states is now: 14
# Set of states removed
# ['ustus']
# these are the states with u transitions to the partition:
# ['ustus']
# []
# Number of states is now: 13
# Set of states removed
# ['tutut']
# these are the states with u transitions to the partition:
# ['tutut']
# []
# Number of states is now: 12
# Set of states removed
# ['ututu']
# these are the states with u transitions to the partition:
# ['ututu']
# []
# Number of states is now: 11
# Set of states removed
# ['ututustutut']
# these are the states with u transitions to the partition:
# ['ututustutut']
# []
# Number of states is now: 10
# Set of states removed
# ['ututut']
# these are the states with u transitions to the partition:
# ['ututut']
# []
# Number of states is now: 9
# Set of states removed
# ['ustutu']
# these are the states with u transitions to the partition:
# ['ustutu']
# []
# Number of states is now: 8
# Set of states removed
# ['tustutu']
# these are the states with u transitions to the partition:
# ['tustutu']
# []
# Number of states is now: 7
# Set of states removed
# ['tustutustutut']
# these are the states with u transitions to the partition:
# ['tustutustutut']
# []
# Number of states is now: 6
# Set of states removed
# ['utustutu']
# these are the states with u transitions to the partition:
# ['utustutu']
# []
# Number of states is now: 5
# Set of states removed
# ['utustutustutut']
# these are the states with u transitions to the partition:
# ['utustutustutut']
# []
# Number of states is now: 4
# Set of states removed
# ['utustutut']
# these are the states with u transitions to the partition:
# ['utustutut']
# []
# Number of states is now: 3
# Set of states removed
# ['tutustutut']
# these are the states with u transitions to the partition:
# ['tutustutut']
# []
# Number of states is now: 2
# Set of states removed
# ['ustutustutut']
# these are the states with u transitions to the partition:
# ['ustutustutut']
# []
# Number of states is now: 1
# Set of states removed
# ['tutustutustutut']
# these are the states with u transitions to the partition:
# ['tutustutustutut']
# []
# [['s'],
#  ['u'],
#  ['t'],
#  ['ts'],
#  ['us', 'ust'],
#  ['ut'],
#  ['uts'],
#  ['tu'],
#  ['tut'],
#  ['tus'],
#  ['tusts'],
#  ['tustu'],
#  ['utu'],
#  ['utut'],
#  ['utus'],
#  ['usts'],
#  ['utusts'],
#  ['ustu'],
#  ['tutu'],
#  ['tutustutu'],
#  ['tustus'],
#  ['ustus'],
#  ['tutut'],
#  ['ututu'],
#  ['ututustutut'],
#  ['ututut'],
#  ['ustutu'],
#  ['tustutu'],
#  ['tustutustutut'],
#  ['utustutu'],
#  ['utustutustutut'],
#  ['utustutut'],
#  ['tutustutut'],
#  ['ustutustutut'],
#  ['tutustutustutut'],
#  ['st',
#   'sts',
#   'stu',
#   'stus',
#   'stutu',
#   'stutut',
#   'stustu',
#   'ustutut',
#   'tustutut',
#   'stutustutu',
#   'stutustutut',
#   'stutustutustutut']]
