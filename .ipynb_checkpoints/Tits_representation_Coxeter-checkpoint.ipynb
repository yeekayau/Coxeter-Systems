# %%
# Input the complete matrix, not just lower triangular

coxeter_matrix = matrix([[1,3,2], [3,1,6],[2,6,1]])

dim_v = coxeter_matrix.rank()
# Vector space over the reals with 100 bits of precision
v = VectorSpace(RealField(100),dim_v)

# %%
coxeter_matrix
# Out:
# [1 3 2]
# [3 1 6]
# [2 6 1]

# %%
def bilinear(x,y):
    '''Computes the bilinear form of two roots'''
    temp = 0
    for i in range(dim_v):
        for j in range(dim_v):
            temp += x[i]*y[j]*(-cos(pi/coxeter_matrix[i,j]))
    return temp

def s(i):
    '''Returns the ith simple root'''
    return v.basis()[i]

def simple_reflection(s,x):
    return x-2*bilinear(x,s)*s

def w_action(word_list,x):
    '''Input a word w in the generators as a list and a root \alpha. Returns w(\alpha)'''
    temp_x = x
    word_list.reverse()
    
    for s in word_list:
        temp_x = simple_reflection(s,temp_x)
    
    # reverse back is it reverses the word outside this function as well
    word_list.reverse()
    
    return temp_x

def inversion_set(w):
    '''Returns the left inversion set of an element w as a list'''
    inversionlist = [w[0]]

    for i in range(len(w)-1):        
        # note: w[0:i+1] does not include the endpoint i+1
        temp = w[0:i+1]
        inversionlist.append(w_action(temp,w[i+1]))
        
    return inversionlist

def elementary_roots():
    '''Returns the set of elementary roots'''
    elementary = []
    
    for i in range(dim_v):
        elementary.append(s(i))
    
    temp_n = 1
    counter = 0
    
    while temp_n < len(elementary):
        
        new_root_counter = 0
        
        temp_n = len(elementary)

        for root in elementary[counter:]:
            for i in range(dim_v):

                temp = w_action([s(i)],root)

                if (temp[i] > root[i]) and (temp[i]-root[i] < 2) and temp not in elementary:
                    elementary.append(temp)
                    new_root_counter += 1
        
        counter = len(elementary) - new_root_counter - 1
                      
    return elementary

def elementary_inversion_set(w, elementary):
    '''returns the left elementary inversion set of an element, but compute the elementary roots first and input it, 
       to avoid recalculating it everytime.'''
    
    inver = inversion_set(w)
    
    e_inversion = [root for root in elementary if root in inver]
    
    return e_inversion

def left_length_increase(word, s):
    '''Tells you whether a word input as a list of simple roots, increases in length by multiplication by s on the left'''
    
    if word[0] == s:
        return False
    
    word_copy = word[:]
    word_copy.reverse()
    
    root = w_action(word_copy,s)
    
    if sum(root) >= 0:
        return True
    else:
        return False
    
def words_are_same_element(word1, word2):
    '''Given two reduced words, determine whether they are the same element 
    by checking if their inversion sets are the same'''
    
    # this only works because we assume words are reduced
    if len(word1) != len(word2):
        return False
  
    w1_inversion = inversion_set(word1)
    w2_inversion = inversion_set(word2)
        
    for root in w1_inversion:
        if root in w2_inversion:
            w2_inversion.remove(root)
    
    if len(w2_inversion) == 0:
        return True
    else:
        return False

def word_nice(word):
    '''prints word as a string of letters'''
    word_string = ''
    for vector in word:
        if vector == s(0):
            word_string += 's'
        elif vector == s(1):
            word_string += 't'
        elif vector == s(2):
            word_string += 'u'
        else:
            word_string += 'v'
    
    return word_string

def wordnice_to_vectorlist(word):
    '''Given a nice presented word returns a list of simple vectors representing the word for computation'''
    word_list = []
    
    for letter in word:
        if letter == 's':
            word_list.append(s(0))
        if letter == 't':
            word_list.append(s(1))
        if letter == 'u':
            word_list.append(s(2))
        if letter == 'v':
            word_list.append(s(3))
    
    return word_list


def elementary_inversion_lists_same(e1, e2):
    '''given two elementary inversion lists, check whether they are the same as sets'''
    if len(e1) != len(e2):
        return False
    
    e1_copy = e1[:]
    
    for root in e1:
        if root in e2:
            e1_copy.remove(root)
        else:
            return False
    
    if len(e1_copy) == 0:
        return True
    else:
        return False

# %%
elementary = elementary_roots()
len(elementary)
# Out:
# 12

# %% [markdown]
# ## Some code for dihedral root subsystems

# %%
import math

def dihedral_root_system(r1, r2):
    '''Returns the root system for the dihedral group generated by the reflections r1 and r2
       input is two reflections as a list
    '''
    
    # Get root associated to reflection 1
    middle_of_r1 = int(math.ceil(len(r1)/2))
    
    if middle_of_r1 - 2==0:
        root1 = w_action([r1[0]],r1[middle_of_r1 - 1])
    elif middle_of_r1 == 1:
        root1 = r1[0]
    else:
        root1 = w_action(r1[0:middle_of_r1 - 1],r1[middle_of_r1 - 1])
    
    # Get root associated to reflection 2
    middle_of_r2 = int(math.ceil(len(r2)/2))
    
    if middle_of_r2 - 2==0:
        root2 = w_action([r2[0]],r2[middle_of_r2 - 1])
    elif middle_of_r2 == 1:
        root2 = r2[0]
    else:
        root2 = w_action(r2[0:middle_of_r2 - 1],r2[middle_of_r2 - 1])
    
    roots = [root1, root2]
    reflections = [r1, r2]
    
    temp_n = 1
    counter = 0
    
    while temp_n < len(roots):
        
        new_root_counter = 0
        
        temp_n = len(roots)
        
        if temp_n > 200:
            print("Looks like this will be an infinite dihedral group. I'm going to stop!!")
            break
        
        for root in roots[counter:]:
            for re in reflections:
                new_root = w_action(re,root)
                
                if new_root not in roots:
                    roots.append(new_root)
                    new_root_counter += 1
        
        counter = len(roots) - new_root_counter - 1
        
    return roots

def positive_roots(subgroup):
    
    pos_roots = []
    
    for el in subgroup:
        if sum(el) > 0:
            pos_roots.append(el)
            
    return pos_roots

# %%
bilinear(w_action([s(0),s(1),s(2)],s(1)),s(0))
# Out:
# 1.0000000000000000000000000000

# %% [markdown]
# ## Construct the Brink-Howlett automata

# %%
def bh_automata():
    '''Returns the list of states, where each item is a list with first index a state
    and then following items in the list are tuples with a transition letter and target state'''

    # list of states and their transition information
    # as elementary inversion lists
    states_transitions = []
    
    # list of states only (as representative word)
    state_list = ['s', 't', 'u']
    
    counter = 0
    num_of_new_states = 1
    
    while num_of_new_states > 0:
        
        num_of_new_states = 0
        
        for state in state_list[counter:]:
            
            counter = len(state_list)-num_of_new_states
            
            state_vector = wordnice_to_vectorlist(state)
            
            state_elementary = elementary_inversion_set(state_vector, elementary)

            state_info = [state]
            
            for j in range(0,dim(v)):
                #print(' ')
                
                generator_word = word_nice([s(j)])
                #print('Word representing inversion set is: ' + state + ' generator is: ' + generator_word )
                
                if left_length_increase(state_vector,s(j)):

                    #print('Yes, ' + state + ' increases on the left by ' + word_nice([s(j)]))
                    
                    target_state = [s(j)] + state_vector
                    target_state_word = word_nice(target_state)
                    
                    #print('Word repping Target State: ' + target_state_word)
                    
                    target_state_elementary_inversion_set = elementary_inversion_set(target_state, elementary)
                    
                    # If target state elementary inversion set is not in the list of states, add to the list.
                    # if already in list, add appropriate transition
                    target_state_is_new = True
                    
                    for st in state_list:
                        st_elementary = elementary_inversion_set(wordnice_to_vectorlist(st), elementary)
                        
                        if elementary_inversion_lists_same(target_state_elementary_inversion_set, st_elementary):
                            #print('Its inversion set is already represented in state_list. It has same e-inversion set as ' + st)
                            
                            transition = (generator_word, st)
                            state_info.append(transition)
                            
                            #print('Added the transition pair (' + generator_word + ', ' + st )
                            
                            target_state_is_new = False
                            break
                    
                    if target_state_is_new == True:
                        # add target_state rep to state list
                        state_list.append(target_state_word)
                        #print('New State. Adding to state_list, the rep: ' + word_nice(target_state))
                        num_of_new_states += 1
                                
                        transition = (generator_word, target_state_word)
                        state_info.append(transition)
                        #print('Added the transition pair (' + generator_word + ', ' + target_state_word )

                #else:
                    #print('No, ' + state + ' decreases by ' + word_nice([s(j)]))
                    
            states_transitions.append(state_info)
        
         
        #print('num_of_new_states: ' + str(num_of_new_states))
        #print('NUMBER OF STATES IS NOW: ' + str(len(state_list)))
        #print('State reps are: ')
        #print(state_list)
        #print('The COUNTER is at: ' + str(counter))
        
    print('Number of states: ' + str(len(state_list)))
    print(state_list)
    return states_transitions

# %%
g2 = bh_automata()
# Out:
# Number of states: 48
# ['s', 't', 'u', 'ts', 'us', 'st', 'ut', 'tu', 'sts', 'uts', 'tus', 'ust', 'tut', 'stu', 'utu', 'usts', 'stus', 'utus', 'utut', 'ustu', 'tutu', 'tusts', 'ustus', 'tutut', 'tustu', 'stutu', 'ututu', 'utusts', 'tustus', 'stutut', 'ututut', 'stustu', 'ustutu', 'ustutut', 'tustutu', 'tustutut', 'utustutu', 'utustutut', 'tutustutu', 'tutustutut', 'stutustutu', 'stutustutut', 'ututustutut', 'ustutustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut', 'stutustutustutut']

# %%
g2
# Out:
# [['s', ('t', 'ts'), ('u', 'us')],
#  ['t', ('s', 'st'), ('u', 'ut')],
#  ['u', ('s', 'us'), ('t', 'tu')],
#  ['ts', ('s', 'sts'), ('u', 'uts')],
#  ['us', ('t', 'tus')],
#  ['st', ('t', 'sts'), ('u', 'ust')],
#  ['ut', ('s', 'ust'), ('t', 'tut')],
#  ['tu', ('s', 'stu'), ('u', 'utu')],
#  ['sts', ('u', 'usts')],
#  ['uts', ('s', 'usts'), ('t', 'tut')],
#  ['tus', ('s', 'stus'), ('u', 'utus')],
#  ['ust', ('t', 'tus')],
#  ['tut', ('s', 'stu'), ('u', 'utut')],
#  ['stu', ('t', 'stus'), ('u', 'ustu')],
#  ['utu', ('s', 'ustu'), ('t', 'tutu')],
#  ['usts', ('t', 'tusts')],
#  ['stus', ('u', 'ustus')],
#  ['utus', ('s', 'ustus'), ('t', 'tutu')],
#  ['utut', ('s', 'ustu'), ('t', 'tutut')],
#  ['ustu', ('t', 'tustu')],
#  ['tutu', ('s', 'stutu'), ('u', 'ututu')],
#  ['tusts', ('s', 'stus'), ('u', 'utusts')],
#  ['ustus', ('t', 'tustus')],
#  ['tutut', ('s', 'stutut'), ('u', 'ututut')],
#  ['tustu', ('s', 'stustu'), ('u', 'utus')],
#  ['stutu', ('t', 'stustu'), ('u', 'ustutu')],
#  ['ututu', ('s', 'ustutu'), ('t', 'ututut')],
#  ['utusts', ('s', 'ustus'), ('t', 'tutut')],
#  ['tustus', ('s', 'stustu'), ('u', 'utusts')],
#  ['stutut', ('t', 'stustu'), ('u', 'ustutut')],
#  ['ututut', ('s', 'ustutut')],
#  ['stustu', ('u', 'ustus')],
#  ['ustutu', ('t', 'tustutu')],
#  ['ustutut', ('t', 'tustutut')],
#  ['tustutu', ('s', 'tustutut'), ('u', 'utustutu')],
#  ['tustutut', ('u', 'utustutut')],
#  ['utustutu', ('s', 'utustutut'), ('t', 'tutustutu')],
#  ['utustutut', ('t', 'tutustutut')],
#  ['tutustutu', ('s', 'stutustutu'), ('u', 'ututu')],
#  ['tutustutut', ('s', 'stutustutut'), ('u', 'ututustutut')],
#  ['stutustutu', ('t', 'stutustutut'), ('u', 'ustutu')],
#  ['stutustutut', ('u', 'ustutustutut')],
#  ['ututustutut', ('s', 'ustutustutut'), ('t', 'ututut')],
#  ['ustutustutut', ('t', 'tustutustutut')],
#  ['tustutustutut', ('s', 'tustutut'), ('u', 'utustutustutut')],
#  ['utustutustutut', ('s', 'utustutut'), ('t', 'tutustutustutut')],
#  ['tutustutustutut', ('s', 'stutustutustutut'), ('u', 'ututut')],
#  ['stutustutustutut', ('t', 'stutustutut'), ('u', 'ustutut')]]

# %%
def Hopcroft(states_transitions):
    '''Applies Hopcroft minimisation to bh-automata'''
    
    # list of states to be emptied
    worklist = []
    
    # worklist starts as a list of strings
    for states in states_transitions:
        worklist.append(states[0])
    
    print("Initial worklist")
    print(worklist)
    
    # copy of list of states inside the list to initiate partition
    # so partition is a list containing one list to start
    partition = [worklist[:]]
    
    print('Initial partition')
    print(partition)
    
    print('Number of partitions initially: ' + str(len(partition)))
    
    while len(worklist) > 0:
        
        print('Number of states left in the worklist is now: ' + str(len(worklist)))
        
        A = worklist[0]
        
        #remove from worklist
        worklist.remove(A)
        
        print('Set of states removed')
        print(A)
            
        if type(A) == str:
            
            for i in range(0,dim_v):
                generator_word = word_nice([s(i)])
                
                states_with_s_i_transition_to_A = []
                
                for st in states_transitions:
                    for transition_info in st[1:]:
                        
                        if transition_info[0] == generator_word and transition_info[1] == A:
                            states_with_s_i_transition_to_A.append(st[0])
                            print(st[0] + ' is a state with ' + generator_word + ' transition to ')
                            print(A)
                
                print('these are the states with ' + generator_word + ' transitions to the single state: ')
                print(A)
                print(states_with_s_i_transition_to_A)
                
                if len(states_with_s_i_transition_to_A) > 0:
                    break
                        
        elif type(A) == list:
            for g in A:
                for i in range(0,dim_v):
                    generator_word = word_nice([s(i)])
                
                    states_with_s_i_transition_to_A = []
                
                    for st in states_transitions:
                        for transition_info in st[1:]:
                            if transition_info[0] == generator_word and transition_info[1] == g[0]:
                                states_with_s_i_transition_to_A.append(st[0])
                                print(st[0] + ' is a state with ' + generator_word + ' transition to ')
                                print(g)
                
                print('these are the states with ' + generator_word + ' transitions to the partition: ')
                print(A)
                print(states_with_s_i_transition_to_A)
                
                if len(states_with_s_i_transition_to_A) > 0:
                    break
                              
        else:
            print('Houston we have a problem')

                        
        if len(states_with_s_i_transition_to_A) > 0:
                
                #counter = 0
                
                #for y in partition[counter:]:
            for y in partition:
                
                print('Element y of partition I am looking at: ')
                print(y)
                    
                y_and_x = [state for state in y if state in states_with_s_i_transition_to_A]

                print('y_and_x is ')
                print(y_and_x)
                    
                y_minus_x = [i for i in y if i not in states_with_s_i_transition_to_A]

                print('y_minus_x is ')
                print(y_minus_x)
                    
                if y_and_x and y_minus_x:
                    index_of_y = partition.index(y)
                    partition.remove(y)
                    partition.insert(index_of_y, y_and_x)
                    partition.insert(index_of_y+1, y_minus_x)
                        
                        #counter += 2

                    print('Partition is now: ')
                    print(partition)
                    
                    print('Number of partitions now: ')
                    print(len(partition))

                    if y in worklist:
                        worklist.remove(y)
                        worklist.append(y_and_x)
                        worklist.append(y_minus_x)
                            
                        print('THE WORKLIST IS NOW:')
                        print(worklist)
                            
                    else: 
                        if len(y_and_x) < len(y_minus_x):
                            worklist.append(y_and_x)
                                
                            print('THE WORKLIST IS NOW:')
                            print(worklist)
                                
                        else:
                            worklist.append(y_minus_x)
                                
                            print('THE WORKLIST IS NOW:')
                            print(worklist)
                        
    return partition

# %%
def transition_cross_check(state, s, partition, automata):
    '''Given a state, a generator s and a partition, this helper function checks the automaton
    to see if the state has an s-transition into a state in the partition.'''
    
    yes_s_trans_to_partition = False
    
    for st in automata:
        if st[0]==state:
            
            for trans in st[1:]:

                if trans[0]==word_nice([s]) and trans[1] in partition:
                                      
                    yes_s_trans_to_partition=True
                    break
        
            break
        
    return yes_s_trans_to_partition


def Hopcroft2(automata):
    ps = []
    pnots = []
    
    # initial split
    for state in automata:
        s_count = 0
        for trans in state[1:]:
            if trans[0]=='s':
                ps.append(state[0])
                s_count += 1
        
        if s_count==0:
            pnots.append(state[0])
    
    partition = []
    partition.append(ps)
    partition.append(pnots)
    
    num_of_splits = 1
    
    while num_of_splits > 0:
        
        num_of_splits = 0
        
        print('Number of splits: ')
        print(num_of_splits)
        
        for p1 in partition:
            
            print('This is p1: ')
            print(p1)
            
            for p2 in partition:
                                
                for i in range(0,dim_v):
                    
                    # checks to see if s is a transition from this partition
                    if left_length_increase(wordnice_to_vectorlist(p1[0]),s(i)):
                                                                 
                        ps1 = [state for state in p1 if transition_cross_check(state, s(i), p2, automata)]
                        
                        
                        if len(ps1) > 0 and ps1 != p1:
                            p_not_s1 = [state for state in p1 if state not in ps1]
                                                       
                            partition.remove(p1)
                            partition.append(ps1)
                            partition.append(p_not_s1)
                            
                            print('Yes, the partition splits')
                            
                            print('Partition is NOW: ')
                            print(partition)
                            print('Number of partitions: ')
                            print(len(partition))
                            
                            
                            num_of_splits += 1
                            
                            break
                    
                if num_of_splits > 0:
                    break
                else:
                    continue
              
            if num_of_splits > 0:
                break
            else:
                continue
        
        print('Finished another round, Num of Splits: ')
        print(num_of_splits)
        
        if num_of_splits == 0:
            break
    
    return partition

# %%
Hopcroft2(g2)
# Out:
# Times Checked: 1
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['t', 'u', 'ts', 'ut', 'tu', 'uts', 'tus', 'tut', 'utu', 'utus', 'utut', 'tutu', 'tusts', 'tutut', 'tustu', 'ututu', 'utusts', 'tustus', 'ututut', 'tustutu', 'utustutu', 'tutustutu', 'tutustutut', 'ututustutut', 'tustutustutut', 'utustutustutut', 'tutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['s', 'us', 'st', 'sts', 'ust', 'stu', 'usts', 'stus', 'ustu', 'ustus', 'stutu', 'stutut', 'stustu', 'ustutu', 'ustutut', 'tustutut', 'utustutut', 'stutustutu', 'stutustutut', 'ustutustutut', 'stutustutustutut'], ['t', 'ts', 'tu', 'tus', 'tut', 'tutu', 'tusts', 'tutut', 'tustu', 'tustus', 'tustutu', 'tutustutu', 'tutustutut', 'tustutustutut', 'tutustutustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'ututu', 'utusts', 'ututut', 'utustutu', 'ututustutut', 'utustutustutut']]
# Number of partitions:
# 3
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 2
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['s', 'us', 'st', 'sts', 'ust', 'stu', 'usts', 'stus', 'ustu', 'ustus', 'stutu', 'stutut', 'stustu', 'ustutu', 'ustutut', 'tustutut', 'utustutut', 'stutustutu', 'stutustutut', 'ustutustutut', 'stutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['t', 'ts', 'tu', 'tus', 'tut', 'tutu', 'tusts', 'tutut', 'tustu', 'tustus', 'tustutu', 'tutustutu', 'tutustutut', 'tustutustutut', 'tutustutustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'ututu', 'utusts', 'ututut', 'utustutu', 'ututustutut', 'utustutustutut'], ['st', 'stu', 'stutu', 'stutut', 'ustutut', 'stutustutu', 'stutustutustutut'], ['s', 'us', 'sts', 'ust', 'usts', 'stus', 'ustu', 'ustus', 'stustu', 'ustutu', 'tustutut', 'utustutut', 'stutustutut', 'ustutustutut']]
# Number of partitions:
# 4
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 3
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['t', 'ts', 'tu', 'tus', 'tut', 'tutu', 'tusts', 'tutut', 'tustu', 'tustus', 'tustutu', 'tutustutu', 'tutustutut', 'tustutustutut', 'tutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'ututu', 'utusts', 'ututut', 'utustutu', 'ututustutut', 'utustutustutut'], ['st', 'stu', 'stutu', 'stutut', 'ustutut', 'stutustutu', 'stutustutustutut'], ['s', 'us', 'sts', 'ust', 'usts', 'stus', 'ustu', 'ustus', 'stustu', 'ustutu', 'tustutut', 'utustutut', 'stutustutut', 'ustutustutut'], ['t', 'tu', 'tut', 'tutu', 'tutut', 'tutustutu', 'tutustutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tutustutut', 'tustutustutut']]
# Number of partitions:
# 5
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 4
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'ututu', 'utusts', 'ututut', 'utustutu', 'ututustutut', 'utustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['st', 'stu', 'stutu', 'stutut', 'ustutut', 'stutustutu', 'stutustutustutut'], ['s', 'us', 'sts', 'ust', 'usts', 'stus', 'ustu', 'ustus', 'stustu', 'ustutu', 'tustutut', 'utustutut', 'stutustutut', 'ustutustutut'], ['t', 'tu', 'tut', 'tutu', 'tutut', 'tutustutu', 'tutustutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tutustutut', 'tustutustutut'], ['ututu', 'ututustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'ututut', 'utustutu', 'utustutustutut']]
# Number of partitions:
# 6
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 5
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['st', 'stu', 'stutu', 'stutut', 'ustutut', 'stutustutu', 'stutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['s', 'us', 'sts', 'ust', 'usts', 'stus', 'ustu', 'ustus', 'stustu', 'ustutu', 'tustutut', 'utustutut', 'stutustutut', 'ustutustutut'], ['t', 'tu', 'tut', 'tutu', 'tutut', 'tutustutu', 'tutustutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tutustutut', 'tustutustutut'], ['ututu', 'ututustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'ututut', 'utustutu', 'utustutustutut'], ['stutut', 'stutustutustutut'], ['st', 'stu', 'stutu', 'ustutut', 'stutustutu']]
# Number of partitions:
# 7
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 6
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['s', 'us', 'sts', 'ust', 'usts', 'stus', 'ustu', 'ustus', 'stustu', 'ustutu', 'tustutut', 'utustutut', 'stutustutut', 'ustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['t', 'tu', 'tut', 'tutu', 'tutut', 'tutustutu', 'tutustutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tutustutut', 'tustutustutut'], ['ututu', 'ututustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'ututut', 'utustutu', 'utustutustutut'], ['stutut', 'stutustutustutut'], ['st', 'stu', 'stutu', 'ustutut', 'stutustutu'], ['s', 'sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut']]
# Number of partitions:
# 8
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 7
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['t', 'tu', 'tut', 'tutu', 'tutut', 'tutustutu', 'tutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tutustutut', 'tustutustutut'], ['ututu', 'ututustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'ututut', 'utustutu', 'utustutustutut'], ['stutut', 'stutustutustutut'], ['st', 'stu', 'stutu', 'ustutut', 'stutustutu'], ['s', 'sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut'], ['tutu', 'tutustutu'], ['t', 'tu', 'tut', 'tutut', 'tutustutustutut']]
# Number of partitions:
# 9
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 8
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tutustutut', 'tustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'ututut', 'utustutu', 'utustutustutut'], ['stutut', 'stutustutustutut'], ['st', 'stu', 'stutu', 'ustutut', 'stutustutu'], ['s', 'sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut'], ['tutu', 'tutustutu'], ['t', 'tu', 'tut', 'tutut', 'tutustutustutut'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut']]
# Number of partitions:
# 10
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 9
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'ututut', 'utustutu', 'utustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['st', 'stu', 'stutu', 'ustutut', 'stutustutu'], ['s', 'sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut'], ['tutu', 'tutustutu'], ['t', 'tu', 'tut', 'tutut', 'tutustutustutut'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut'], ['ututut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'utustutu', 'utustutustutut']]
# Number of partitions:
# 11
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 10
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['st', 'stu', 'stutu', 'ustutut', 'stutustutu']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['s', 'sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut'], ['tutu', 'tutustutu'], ['t', 'tu', 'tut', 'tutut', 'tutustutustutut'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut'], ['ututut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'utustutu', 'utustutustutut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut']]
# Number of partitions:
# 12
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 11
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['s', 'sts', 'stus', 'stustu', 'tustutut', 'stutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut'], ['tutu', 'tutustutu'], ['t', 'tu', 'tut', 'tutut', 'tutustutustutut'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut'], ['ututut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'utustutu', 'utustutustutut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['sts', 'stus', 'stustu', 'tustutut', 'stutustutut']]
# Number of partitions:
# 13
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 12
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'utustutut', 'ustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['t', 'tu', 'tut', 'tutut', 'tutustutustutut'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut'], ['ututut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'utustutu', 'utustutustutut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['utustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'ustutustutut']]
# Number of partitions:
# 14
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 13
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['t', 'tu', 'tut', 'tutut', 'tutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut'], ['ututut'], ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'utustutu', 'utustutustutut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['utustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'ustutustutut'], ['tutut', 'tutustutustutut'], ['t', 'tu', 'tut']]
# Number of partitions:
# 15
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 14
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['u', 'ut', 'uts', 'utu', 'utus', 'utut', 'utusts', 'utustutu', 'utustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['utustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'ustutustutut'], ['tutut', 'tutustutustutut'], ['t', 'tu', 'tut'], ['utu', 'utus', 'utustutu'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut']]
# Number of partitions:
# 16
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 15
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ts', 'tus', 'tusts', 'tustu', 'tustus', 'tustutu', 'tustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['sts', 'stus', 'stustu', 'tustutut', 'stutustutut'], ['utustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'ustutustutut'], ['tutut', 'tutustutustutut'], ['t', 'tu', 'tut'], ['utu', 'utus', 'utustutu'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut']]
# Number of partitions:
# 17
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 16
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['sts', 'stus', 'stustu', 'tustutut', 'stutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'ustutustutut'], ['tutut', 'tutustutustutut'], ['t', 'tu', 'tut'], ['utu', 'utus', 'utustutu'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut']]
# Number of partitions:
# 18
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 17
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['us', 'ust', 'usts', 'ustu', 'ustus', 'ustutu', 'ustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['ututu', 'ututustutut'], ['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['t', 'tu', 'tut'], ['utu', 'utus', 'utustutu'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut']]
# Number of partitions:
# 19
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 18
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['ututu', 'ututustutut']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['t', 'tu', 'tut'], ['utu', 'utus', 'utustutu'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut']]
# Number of partitions:
# 20
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 19
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['t', 'tu', 'tut']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['utu', 'utus', 'utustutu'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut']]
# Number of partitions:
# 21
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 20
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['utu', 'utus', 'utustutu']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus']]
# Number of partitions:
# 22
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 21
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['u', 'ut', 'uts', 'utut', 'utusts', 'utustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tus', 'tustu', 'tustutu'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts']]
# Number of partitions:
# 23
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 22
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['tus', 'tustu', 'tustutu']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['ts', 'tusts', 'tustus', 'tustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu']]
# Number of partitions:
# 24
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 23
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['ts', 'tusts', 'tustus', 'tustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['us', 'ust', 'ustu', 'ustutu'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus']]
# Number of partitions:
# 25
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 24
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['sts', 'stus', 'stustu', 'stutustutut']
# This is p1:
# ['us', 'ust', 'ustu', 'ustutu']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['st', 'stu', 'stutu', 'stutustutu'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu']]
# Number of partitions:
# 26
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 25
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['st', 'stu', 'stutu', 'stutustutu']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['usts', 'ustus', 'ustutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu']]
# Number of partitions:
# 27
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 26
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['sts', 'stus', 'stustu', 'stutustutut']
# This is p1:
# ['usts', 'ustus', 'ustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tustutut'], ['sts', 'stus', 'stustu', 'stutustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus']]
# Number of partitions:
# 28
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 27
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['sts', 'stus', 'stustu', 'stutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['stutut', 'stutustutustutut'], ['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu']]
# Number of partitions:
# 29
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 28
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['stutut', 'stutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tutut', 'tutustutustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut']]
# Number of partitions:
# 30
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 29
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tutut', 'tutustutustutut']
# Yes, the partition splits
# Partition is NOW:
# [['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utu', 'utus'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut']]
# Number of partitions:
# 31
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 30
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['t', 'tut']
# This is p1:
# ['utustutu']
# This is p1:
# ['utu', 'utus']
# Yes, the partition splits
# Partition is NOW:
# [['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utustutustutut'], ['u', 'ut', 'uts', 'utut', 'utusts'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus']]
# Number of partitions:
# 32
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 31
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['t', 'tut']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['u', 'ut', 'uts', 'utut', 'utusts']
# Yes, the partition splits
# Partition is NOW:
# [['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['stutu', 'stutustutu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['ut', 'uts', 'utut', 'utusts']]
# Number of partitions:
# 33
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 32
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutu', 'tutustutu']
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['t', 'tut']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['tustutu']
# This is p1:
# ['tus', 'tustu']
# This is p1:
# ['tustutustutut']
# This is p1:
# ['ts', 'tusts', 'tustus']
# This is p1:
# ['ustutu']
# This is p1:
# ['us', 'ust', 'ustu']
# This is p1:
# ['stutu', 'stutustutu']
# Yes, the partition splits
# Partition is NOW:
# [['tutu', 'tutustutu'], ['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['ut', 'uts', 'utut', 'utusts'], ['stutustutu'], ['stutu']]
# Number of partitions:
# 34
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 33
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutu', 'tutustutu']
# Yes, the partition splits
# Partition is NOW:
# [['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['ut', 'uts', 'utut', 'utusts'], ['stutustutu'], ['stutu'], ['tutustutu'], ['tutu']]
# Number of partitions:
# 35
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 34
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['t', 'tut']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['tustutu']
# This is p1:
# ['tus', 'tustu']
# This is p1:
# ['tustutustutut']
# This is p1:
# ['ts', 'tusts', 'tustus']
# This is p1:
# ['ustutu']
# This is p1:
# ['us', 'ust', 'ustu']
# This is p1:
# ['st', 'stu']
# This is p1:
# ['ustutustutut']
# This is p1:
# ['usts', 'ustus']
# This is p1:
# ['stutustutut']
# This is p1:
# ['sts', 'stus', 'stustu']
# This is p1:
# ['stutustutustutut']
# This is p1:
# ['stutut']
# This is p1:
# ['tutustutustutut']
# This is p1:
# ['tutut']
# This is p1:
# ['utu']
# This is p1:
# ['utus']
# This is p1:
# ['u']
# This is p1:
# ['ut', 'uts', 'utut', 'utusts']
# Yes, the partition splits
# Partition is NOW:
# [['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['t', 'tut'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['stutustutu'], ['stutu'], ['tutustutu'], ['tutu'], ['ut', 'uts'], ['utut', 'utusts']]
# Number of partitions:
# 36
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 35
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['t', 'tut']
# Yes, the partition splits
# Partition is NOW:
# [['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ts', 'tusts', 'tustus'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['stutustutu'], ['stutu'], ['tutustutu'], ['tutu'], ['ut', 'uts'], ['utut', 'utusts'], ['t'], ['tut']]
# Number of partitions:
# 37
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 36
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['tustutu']
# This is p1:
# ['tus', 'tustu']
# This is p1:
# ['tustutustutut']
# This is p1:
# ['ts', 'tusts', 'tustus']
# Yes, the partition splits
# Partition is NOW:
# [['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['stutustutu'], ['stutu'], ['tutustutu'], ['tutu'], ['ut', 'uts'], ['utut', 'utusts'], ['t'], ['tut'], ['ts'], ['tusts', 'tustus']]
# Number of partitions:
# 38
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 37
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['tustutu']
# This is p1:
# ['tus', 'tustu']
# This is p1:
# ['tustutustutut']
# This is p1:
# ['ustutu']
# This is p1:
# ['us', 'ust', 'ustu']
# This is p1:
# ['st', 'stu']
# This is p1:
# ['ustutustutut']
# This is p1:
# ['usts', 'ustus']
# This is p1:
# ['stutustutut']
# This is p1:
# ['sts', 'stus', 'stustu']
# This is p1:
# ['stutustutustutut']
# This is p1:
# ['stutut']
# This is p1:
# ['tutustutustutut']
# This is p1:
# ['tutut']
# This is p1:
# ['utu']
# This is p1:
# ['utus']
# This is p1:
# ['u']
# This is p1:
# ['stutustutu']
# This is p1:
# ['stutu']
# This is p1:
# ['tutustutu']
# This is p1:
# ['tutu']
# This is p1:
# ['ut', 'uts']
# Yes, the partition splits
# Partition is NOW:
# [['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['stutustutu'], ['stutu'], ['tutustutu'], ['tutu'], ['utut', 'utusts'], ['t'], ['tut'], ['ts'], ['tusts', 'tustus'], ['ut'], ['uts']]
# Number of partitions:
# 39
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 38
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['tustutu']
# This is p1:
# ['tus', 'tustu']
# This is p1:
# ['tustutustutut']
# This is p1:
# ['ustutu']
# This is p1:
# ['us', 'ust', 'ustu']
# This is p1:
# ['st', 'stu']
# This is p1:
# ['ustutustutut']
# This is p1:
# ['usts', 'ustus']
# This is p1:
# ['stutustutut']
# This is p1:
# ['sts', 'stus', 'stustu']
# This is p1:
# ['stutustutustutut']
# This is p1:
# ['stutut']
# This is p1:
# ['tutustutustutut']
# This is p1:
# ['tutut']
# This is p1:
# ['utu']
# This is p1:
# ['utus']
# This is p1:
# ['u']
# This is p1:
# ['stutustutu']
# This is p1:
# ['stutu']
# This is p1:
# ['tutustutu']
# This is p1:
# ['tutu']
# This is p1:
# ['utut', 'utusts']
# Yes, the partition splits
# Partition is NOW:
# [['tutustutut'], ['ututut'], ['ustutut'], ['s'], ['utustutut'], ['tustutut'], ['ututu'], ['ututustutut'], ['tu'], ['utustutu'], ['utustutustutut'], ['tustutu'], ['tus', 'tustu'], ['tustutustutut'], ['ustutu'], ['us', 'ust', 'ustu'], ['st', 'stu'], ['ustutustutut'], ['usts', 'ustus'], ['stutustutut'], ['sts', 'stus', 'stustu'], ['stutustutustutut'], ['stutut'], ['tutustutustutut'], ['tutut'], ['utu'], ['utus'], ['u'], ['stutustutu'], ['stutu'], ['tutustutu'], ['tutu'], ['t'], ['tut'], ['ts'], ['tusts', 'tustus'], ['ut'], ['uts'], ['utut'], ['utusts']]
# Number of partitions:
# 40
# Breaking from p2 loop
# breaking from p1 loop
# Finished another round, Num of Splits:
# 1
# Times Checked: 39
# Starting again!!!
# Number of splits:
# 0
# This is p1:
# ['tutustutut']
# This is p1:
# ['ututut']
# This is p1:
# ['ustutut']
# This is p1:
# ['s']
# This is p1:
# ['utustutut']
# This is p1:
# ['tustutut']
# This is p1:
# ['ututu']
# This is p1:
# ['ututustutut']
# This is p1:
# ['tu']
# This is p1:
# ['utustutu']
# This is p1:
# ['utustutustutut']
# This is p1:
# ['tustutu']
# This is p1:
# ['tus', 'tustu']
# This is p1:
# ['tustutustutut']
# This is p1:
# ['ustutu']
# This is p1:
# ['us', 'ust', 'ustu']
# This is p1:
# ['st', 'stu']
# This is p1:
# ['ustutustutut']
# This is p1:
# ['usts', 'ustus']
# This is p1:
# ['stutustutut']
# This is p1:
# ['sts', 'stus', 'stustu']
# This is p1:
# ['stutustutustutut']
# This is p1:
# ['stutut']
# This is p1:
# ['tutustutustutut']
# This is p1:
# ['tutut']
# This is p1:
# ['utu']
# This is p1:
# ['utus']
# This is p1:
# ['u']
# This is p1:
# ['stutustutu']
# This is p1:
# ['stutu']
# This is p1:
# ['tutustutu']
# This is p1:
# ['tutu']
# This is p1:
# ['t']
# This is p1:
# ['tut']
# This is p1:
# ['ts']
# This is p1:
# ['tusts', 'tustus']
# This is p1:
# ['ut']
# This is p1:
# ['uts']
# This is p1:
# ['utut']
# This is p1:
# ['utusts']
# Finished another round, Num of Splits:
# 0
# [['tutustutut'],
#  ['ututut'],
#  ['ustutut'],
#  ['s'],
#  ['utustutut'],
#  ['tustutut'],
#  ['ututu'],
#  ['ututustutut'],
#  ['tu'],
#  ['utustutu'],
#  ['utustutustutut'],
#  ['tustutu'],
#  ['tus', 'tustu'],
#  ['tustutustutut'],
#  ['ustutu'],
#  ['us', 'ust', 'ustu'],
#  ['st', 'stu'],
#  ['ustutustutut'],
#  ['usts', 'ustus'],
#  ['stutustutut'],
#  ['sts', 'stus', 'stustu'],
#  ['stutustutustutut'],
#  ['stutut'],
#  ['tutustutustutut'],
#  ['tutut'],
#  ['utu'],
#  ['utus'],
#  ['u'],
#  ['stutustutu'],
#  ['stutu'],
#  ['tutustutu'],
#  ['tutu'],
#  ['t'],
#  ['tut'],
#  ['ts'],
#  ['tusts', 'tustus'],
#  ['ut'],
#  ['uts'],
#  ['utut'],
#  ['utusts']]
